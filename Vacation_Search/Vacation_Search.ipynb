# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID      City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0    Calama      CL -22.4667  -68.9333     52.29        17
# 1        1    Wabash      US  40.7978  -85.8205     81.12        74
# 2        2     Bluff      NZ -46.6000  168.3333     41.81        58
# 3        3      Sola      VU -13.8833  167.5500     80.17        79
# 4        4  Katsuura      JP  35.1333  140.3000     73.71        87
#
#    Cloudiness  Wind Speed Current Description
# 0           0       16.11           clear sky
# 1           4        7.18           clear sky
# 2          82        6.38       broken clouds
# 3          94       17.74     overcast clouds
# 4          58        9.48       broken clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
# 4a-b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)].dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = None
hotel_df.head(10)
# Out:
#           City Country  Max Temp Current Description      Lat       Lng  \
# 1       Wabash      US     81.12           clear sky  40.7978  -85.8205
# 3         Sola      VU     80.17     overcast clouds -13.8833  167.5500
# 5      Rikitea      PF     75.58           clear sky -23.1203 -134.9692
# 6     Ahuimanu      US     83.34          light rain  21.4447 -157.8378
# 9    Hithadhoo      MV     83.93    scattered clouds  -0.6000   73.0833
# 13    Douentza      ML     85.82     overcast clouds  14.9951   -2.9517
# 14    Waingapu      ID     82.00    scattered clouds  -9.6567  120.2641
# 16  Butaritari      KI     81.46       moderate rain   3.0707  172.7902
# 18       Vaini      TO     77.16          few clouds -21.2000 -175.2000
# 22      Atuona      PF     78.35           clear sky  -9.8000 -139.0333
#
#    Hotel Name
# 1        None
# 3        None
# 5        None
# 6        None
# 9        None
# 13       None
# 14       None
# 16       None
# 18       None
# 22       None

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key,
    "location": ""
}

# 6b. Iterate through the hotel DataFrame.
print("-------------------------------------------------------------------------")
print("---------------Searching for hotels at suitable locations----------------")
print("-------------------------------------------------------------------------")
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # 6e. Make request and retrieve the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # 6f. Grab the first hotel from the results and store the name.
    try:
        hotel_name = hotels["results"][0]["name"]
        hotel_df.loc[index, "Hotel Name"] = hotel_name
        city = hotel_df.loc[index, "City"]
        print(f"Found {hotel_name} near {city}.")
    except (IndexError):
        print(f"No hotels near {city}... skipping.") 
        
print("-------------------------------------------------------------------------")
print("-----------------------------Search complete-----------------------------")
print("-------------------------------------------------------------------------")
# Out:
# -------------------------------------------------------------------------
# ---------------Searching for hotels at suitable locations----------------
# -------------------------------------------------------------------------
# Found Holiday Inn Express & Suites Wabash, an IHG Hotel near Wabash.
# Found Leumerus Bungalows near Sola.
# Found People ThankYou near Rikitea.
# Found Paradise Bay Resort near Ahuimanu.
# Found Scoop Guest House near Hithadhoo.
# Found Ogomono Doumbo near Douentza.
# Found Pondok Wisata Elim near Waingapu.
# Found Isles Sunset Lodge near Butaritari.
# Found Keleti Beach Resort near Vaini.
# Found Villa Enata near Atuona.
# Found Hotel Viktoria near Dudinka.
# Found Mantra Trilogy Cairns near Cairns.
# Found Casa juvenil Sor Amanda Bedoya near El Tarra.
# Found Hotel Silva near Porto Walter.
# No hotels near Porto Walter... skipping.
# Found Paradise Inn near Avarua.
# Found Hilo Hawaiian Hotel near Hilo.
# No hotels near Hilo... skipping.
# Found Cititel Penang near Georgetown.
# Found Mini Central near Victoria.
# Found Inubosaki Kanko Hotel near Hasaki.
# Found Tarawa Boutique Hotel near Bairiki.
# No hotels near Bairiki... skipping.
# Found hotel la terminal near Ixtapa.
# Found Derogongan Residence near Marawi.
# Found Expeditions Ténére voyages near Bilma.
# Found HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel near Salalah.
# Found Bonthe Holiday Village near Bonthe.
# Found Aklavik Inn near Aklavik.
# Found Sunscape Splash Montego Bay near Montego Bay.
# Found Bora-Bora Pearl Beach Resort & Spa near Faanui.
# Found Sri Selvi Lodge near Kangayam.
# Found Nusa Island Retreat near Kavieng.
# Found Taitung Bali Suites Hotel near Taitung.
# Found Kamaneahn Hotel Inc near Buchanan.
# Found DoubleTree Suites by Hilton Hotel Lexington near Lexington.
# Found Hotel Juba near Mogadishu.
# Found Wine Stopper B&B near Peachland.
# Found Atlântic Hotel near Codajas.
# No hotels near Codajas... skipping.
# Found FairBridge Inn & Suites Miles City near Miles City.
# No hotels near Miles City... skipping.
# Found SEGAYA PROPERTY near Dingle.
# Found Sur Plaza Hotel near Sur.
# Found Suoxing Hotel near Linfen.
# Found Villa Orphee near Les Cayes.
# Found Embassy Suites by Hilton Portland Downtown near Portland.
# Found Bungalow 63 near Hambantota.
# Found SureStay near Ashland.
# Found Pirineos near San Cristobal.
# Found Ерлан үй near Zaysan.
# Found Mystic Sands Beachfront Accommodation near Neiafu.
# No hotels near Neiafu... skipping.
# Found Algys near Amga.
# Found Maui Seaside Hotel near Kahului.
# Found ALETHEIA Appartement Sinnamary near Sinnamary.
# Found Sheraton Kauai Coconut Beach Resort near Kapaa.
# Found Holiday Inn Express Lompoc, an IHG Hotel near Lompoc.
# Found Canalta Hotel Assiniboia near Assiniboia.
# Found Zhangye Lvzhou Holiday Inn near Zhangye.
# Found JM Lodge near Alugan.
# Found Hotel Meligai Kapit near Kapit.
# Found Hôtel Le Dronmi near Cayenne.
# No hotels near Cayenne... skipping.
# Found Taloa Heights near Alofi.
# Found Chernyseyskiy near Chernyshevskiy.
# Found Niyama Private Islands Maldives near Kudahuvadhoo.
# Found Fakhamat Al Orjoana Apartment near Sakakah.
# Found Kost Pria near Meulaboh.
# Found VS Villa near Kalmunai.
# Found Base Lodging near Ewa Beach.
# Found Khách sạn Sài Gòn Bạc Liêu near Bac Lieu.
# Found Motel 6 Sinton, TX near San Patricio.
# Found Pike's Waterfront Lodge near College.
# Found Bungalows Guesthouse near Tahoua.
# Found Puri Brata near Bambanglipuro.
# Found آپارتمان بزرگ اویسا near Kazerun.
# Found Hôtel Le Lagon near Noumea.
# Found Talnakh Hotel near Talnakh.
# Found ООО "Туруханская пушнина" near Turukhansk.
# Found دوار ال عبد الجواد شرق البلد بابنوب near Abnub.
# Found Green Park Inn Hotel near Pak Phanang.
# Found Aipana Plaza Hotel near Boa Vista.
# Found Grage Hotel Bengkulu near Bengkulu.
# Found SanBiz Lodge near Kirakira.
# Found Maringe Lagoon Lodge near Buala.
# Found Laxmi Hotel near Lachhmangarh.
# No hotels near Lachhmangarh... skipping.
# Found Hotel El Manantial near San Carlos Del Zulia.
# Found É Antônio de Souza construção near Jose De Freitas.
# Found Osprey Beach Hotel near Cockburn Town.
# Found ZINGARA 76ft Catamaran, full crew-all included near Road Town.
# Found Hotel Hacienda de los Galvez near Colotlan.
# Found Holiday Inn Express & Suites Lander, an IHG Hotel near Lander.
# Found Atlantis Hotel near Bathsheba.
# Found Residence Inn by Marriott Clearwater Downtown near Clearwater.
# Found Casa de Campo Resort and Villas near La Romana.
# Found El rranchito michuacan de ocampos near Coahuayana.
# Found APEPDCL near Parlakimidi.
# Found Erenhot Rurouni Youth Hostel near Erenhot.
# Found Hotel Tara Plage near Kribi.
# Found The Esplanade Hotel near Port Hedland.
# Found Hotel Xaguate near Sao Filipe.
# Found Esquivel's Garden And Resort near San Pedro.
# Found InterContinental Riyadh, an IHG Hotel near Riyadh.
# Found Rio Xingu Camping near Sao Felix Do Xingu.
# Found Numsai Khaosuay Resort Ranong near Ranong.
# No hotels near Ranong... skipping.
# No hotels near Ranong... skipping.
# Found Seasun Beach Resort & Hotel near Bolitoc.
# Found Severnoye Siyaniye near Udachnyy.
# Found OYO 37021 Hotel Sitar International near Sitarganj.
# Found Aspen Extended Stay Suites near Kenai.
# No hotels near Kenai... skipping.
# Found Hamza hotel jiwani near Jiwani.
# No hotels near Jiwani... skipping.
# Found Heritage Hotel near Norman Wells.
# Found Sylvia Hotel near Maumere.
# Found Auki Motel near Auki.
# Found PATHFINDER near Contai.
# Found Hostal Rio Miel near Baracoa.
# Found Hotel California Todos Santos near Todos Santos.
# No hotels near Todos Santos... skipping.
# Found Grand Trisula Hotel near Indramayu.
# Found Hilton Garden Inn Qidong near Huilong.
# Found Lamana Hotel (Port Moresby) near Port Moresby.
# Found Pousada Maria Bonita near Urucara.
# Found Tanna Lodge near Isangel.
# Found Best Western Plus Clocktower Inn near Billings.
# Found Seagulls Inn Namatani near Namatanai.
# Found Maitai Lapita Village Huahine near Fare.
# Found Hilton Garden Inn Omaha West near Douglas.
# Found The Ritz-Carlton, Half Moon Bay near Half Moon Bay.
# Found Hotel California Petatlán near Petatlan.
# Found Grafika Hotel Dan Restoran near Gombong.
# Found Apel'sin near Khandyga.
# Found Best Western Pahrump Oasis near Pahrump.
# Found Wolong Village near Jinxiang.
# Found Taiyuan Wanda Wenhua Hotel near Taiyuan.
# Found Nuli Sapi near Samarai.
# Found Shanghai Hotel near Zaoyang.
# Found CeBlue Villas & Beach Resort near The Valley.
# Found Kirari Guest House near Gushikawa.
# Found DoubleFAG near Labuhan.
# Found Amit kirana store near Amarpur.
# Found Benjie's Kubo & Cottages near Catuday.
# Found Lorengau Harbourside Hotel near Lorengau.
# Found AVK events and catering near Narasannapeta.
# Found Penginapan Kim near Biak.
# Found Uruna Bay Retreat near Kieta.
# Found Iftin hotel hobyo near Hobyo.
# Found Posada Lilia near Celestun.
# Found 雲林商務旅館—芳斯華 near Tuku.
# Found Moevenpick Enshi near Enshi.
# Found Camp Pālehua near Nanakuli.
# Found Oasi di Kufra near Sabaudia.
# Found Groote Eylandt Lodge near Alyangula.
# Found Eastgate Hotel near Kapoeta.
# Found JABIR HOTEL near Bandarbeyla.
# Found Hotel Nusantara I near Nabire.
# Found M.O.S. Logística - Filial Fortaleza near Caucaia.
# Found Casa Gualberto - Deysi near Bahia Honda.
# Found Hotel Pala Palace near Pala.
# Found R S Residency near Raxaul.
# Found Shishime Hotel near Naze.
# Found Hotel West near Along.
# Found A Beach Retreat On Casey Key near Venice.
# Found Radisson Grenada Beach Resort near Saint-Georges.
# Found บ้านไทโฮมสเตย์&รีสอร์ท จ.สตูล near Satun.
# Found Mövenpick Qassim near Buraydah.
# Found Hotel Octave Maldives near Male.
# Found Mohan sharma house near Khunti.
# Found Hampton Inn & Suites Scottsbluff-Conference Center near Scottsbluff.
# Found Umit near Makat.
# Found Rama Spa near Chalus.
# Found 7 Makara Hotel near Kampong Cham.
# Found Recanto dos Ferreiras near Mazagao.
# Found Holiday Inn Express Roseville-St. Paul near Saint Anthony.
# Found Alaska's Select Inn Wasilla near Wasilla.
# Found Hotel Colombia Real - Cartagena near Cartagena.
# Found Hotel Gaudi near Mindelo.
# Found Hotel los Mangos near Teacapan.
# Found Bam Tourist Hotel near Bam.
# Found Casa Juazeiro near Nova Olinda Do Norte.
# Found hotêl doufoulougou near Tabou.
# Found HOTEL ISABELA near Amahai.
# Found Hotel RIKMAN Continental near Tura.
# No hotels near Tura... skipping.
# Found Mrs Luis Guest House near Lampang.
# Found Hotel Castilla near Las Lomas.
# Found Le Roi Raipur Hotel near Raipur.
# Found Gaya Centre Hotel near Kota Kinabalu.
# Found काव्या बुटिक near Harrai.
# Found Hotel casa real near Puerto Suarez.
# Found Mercure Padang near Padang.
# Found Daru Lodge near Daru.
# Found Cabañas City Heart near Santo Domingo.
# Found Travelodge by Wyndham La Grande near La Grande.
# Found Southern Beach Hotel & Resort Okinawa near Itoman.
# Found Heritage Park Hotel near Honiara.
# Found Agapita M. Nicart near San Policarpo.
# Found Pacifica Lighthouse, Trademark Collection by Wyndham near Pacifica.
# Found میزان کفری near Kifri.
# Found Hotels in Lakshadweep Islands near Kavaratti.
# Found Nathaniel's Lodge near Basco.
# Found Sambharia Bhawan,Kuchaman Road,Nawa City near Nawa.
# Found East Arnhem Real Estate near Nhulunbuy.
# Found Le Rocher de Tahiti near Tiarei.
# Found Soneva Fushi near Eydhafushi.
# Found Hotel Kununurra near Kununurra.
# Found Malecón Ecoturistico Sabanagrande near Sabanagrande.
# Found Cj's Travellers Inn near Gigmoto.
# Found Crowne Plaza Ordos near Dongsheng.
# Found Hotel La Ballena Azul near Santa Marta.
# Found Butterfly Beach Hotel near Oistins.
# Found Six Acres Bed & Breakfast near Hamilton.
# Found The Hamsa Resort near Banjar.
# Found Guest House Ruslan Nurata & Tours near Nurota.
# Found Hotel y restaurante "El Diamante" near Champerico.
# Found Nanning Travelling With Hostel near Nanning.
# Found Welcomhotel By ITC Hotels, Bay Island, Port Blair near Port Blair.
# Found Vahmoneh Lodge Vanimo near Vanimo.
# Found Swiss-Belhotel Ambon near Ambon.
# Found مجتمع مرصاد near Garmsar.
# Found Dhidhoo beach near Dhidhdhoo.
# Found OYO 884 Rumoh PMI Hotel near Banda Aceh.
# Found Maharaja Hotel near Suratgarh.
# Found Waigo Splash Hotel near Sorong.
# Found Imagination Island near Gizo.
# Found Ramkota Hotel near Pierre.
# No hotels near Pierre... skipping.
# Found Red Sea Resort & Suites Mandera County near Mandera.
# Found HS Hotsson Smart Acapulco near Acapulco.
# Found شهدان. ابوالحجر near Jizan.
# Found Jiugang Hotel - Jiayuguan near Jiayuguan.
# Found Shell Shandong Liaocheng Development District South Huangshan Road Hotel near Rongcheng.
# Found Crowne Plaza Lansing West, an IHG Hotel near Waverly.
# Found Yingbin Hotel near Shitanjing.
# Found GUEST INN near Gusau.
# Found Fairfield Inn & Suites by Marriott St. Louis West/Wentzville near Wentzville.
# Found Oota Ryokan near Muroto.
# Found Aryaduta Makassar near Makasar.
# Found Sunimit Mansion near Phangnga.
# -------------------------------------------------------------------------
# -----------------------------Search complete-----------------------------
# -------------------------------------------------------------------------

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df = hotel_df.dropna()
hotel_df
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 1        Wabash      US     81.12           clear sky  40.7978  -85.8205
# 3          Sola      VU     80.17     overcast clouds -13.8833  167.5500
# 5       Rikitea      PF     75.58           clear sky -23.1203 -134.9692
# 6      Ahuimanu      US     83.34          light rain  21.4447 -157.8378
# 9     Hithadhoo      MV     83.93    scattered clouds  -0.6000   73.0833
# ..          ...     ...       ...                 ...      ...       ...
# 685       Gusau      NG     80.20    scattered clouds  12.1628    6.6614
# 688  Wentzville      US     85.05          few clouds  38.8114  -90.8529
# 689      Muroto      JP     78.10           clear sky  33.2833  134.1500
# 696     Makasar      ID     78.85          few clouds  -5.1400  119.4221
# 702    Phangnga      TH     78.84     overcast clouds   8.4509   98.5298
#
#                                             Hotel Name
# 1    Holiday Inn Express & Suites Wabash, an IHG Hotel
# 3                                   Leumerus Bungalows
# 5                                      People ThankYou
# 6                                  Paradise Bay Resort
# 9                                    Scoop Guest House
# ..                                                 ...
# 685                                          GUEST INN
# 688  Fairfield Inn & Suites by Marriott St. Louis W...
# 689                                        Oota Ryokan
# 696                                  Aryaduta Makassar
# 702                                    Sunimit Mansion
#
# [228 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.8)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
