# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
from citipy import citipy
from config import weather_api_key

# %%
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-180,180,size=2000)
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
print(f"Number of cities generated: {len(cities)}")
# Out:
# Number of cities generated: 766

# %%
# Build base url for api requests
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all cities
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_dscript = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_dscript})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | calama
# Processing Record 2 of Set 1 | wabash
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | sola
# Processing Record 5 of Set 1 | katsuura
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | ahuimanu
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | itarema
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | rodionovo-nesvetayskaya
# Processing Record 12 of Set 1 | rio gallegos
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | douentza
# Processing Record 15 of Set 1 | waingapu
# Processing Record 16 of Set 1 | odenthal
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | constitucion
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | grootfontein
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 1 | dudinka
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | iqaluit
# Processing Record 32 of Set 1 | cairns
# Processing Record 33 of Set 1 | el tarra
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | porto walter
# Processing Record 36 of Set 1 | marzuq
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | dunedin
# Processing Record 40 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 1 | clyde river
# Processing Record 42 of Set 1 | gladstone
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | cuetzalan
# Processing Record 45 of Set 1 | shiraoi
# Processing Record 46 of Set 1 | dukat
# Processing Record 47 of Set 1 | catalao
# Processing Record 48 of Set 1 | petrovsk-zabaykalskiy
# Processing Record 49 of Set 1 | tiznit
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | barra patuca
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | sitka
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | victoria
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | baoro
# Processing Record 8 of Set 2 | hasaki
# Processing Record 9 of Set 2 | san jose
# Processing Record 10 of Set 2 | bairiki
# Processing Record 11 of Set 2 | bartica
# Processing Record 12 of Set 2 | narsaq
# Processing Record 13 of Set 2 | axim
# Processing Record 14 of Set 2 | ossora
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 2 | leningradskiy
# Processing Record 18 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 2 | thiadiaye
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | svetlogorsk
# Processing Record 23 of Set 2 | deputatskiy
# Processing Record 24 of Set 2 | nizhnevartovsk
# Processing Record 25 of Set 2 | saint george
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | verkhoyansk
# Processing Record 28 of Set 2 | skibbereen
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | coihaique
# Processing Record 31 of Set 2 | cooma
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | vestmannaeyjar
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | camacha
# Processing Record 38 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 2 | coquimbo
# Processing Record 40 of Set 2 | ixtapa
# Processing Record 41 of Set 2 | marawi
# Processing Record 42 of Set 2 | bilma
# Processing Record 43 of Set 2 | yerofey pavlovich
# Processing Record 44 of Set 2 | nome
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | salalah
# Processing Record 47 of Set 2 | bonthe
# Processing Record 48 of Set 2 | hobart
# Processing Record 49 of Set 2 | aklavik
# Processing Record 50 of Set 2 | bowen
# Processing Record 1 of Set 3 | vestbygda
# City not found. Skipping...
# Processing Record 2 of Set 3 | barrow
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | punta arenas
# Processing Record 5 of Set 3 | acari
# Processing Record 6 of Set 3 | tungkang
# City not found. Skipping...
# Processing Record 7 of Set 3 | busselton
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | krasnoselkup
# Processing Record 10 of Set 3 | montego bay
# Processing Record 11 of Set 3 | faanui
# Processing Record 12 of Set 3 | esperance
# Processing Record 13 of Set 3 | mysen
# Processing Record 14 of Set 3 | kangayam
# Processing Record 15 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 3 | prince rupert
# Processing Record 17 of Set 3 | hammerfest
# Processing Record 18 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 3 | abiy adi
# City not found. Skipping...
# Processing Record 22 of Set 3 | dikson
# Processing Record 23 of Set 3 | savelugu
# Processing Record 24 of Set 3 | kosonsoy
# Processing Record 25 of Set 3 | kavieng
# Processing Record 26 of Set 3 | grand gaube
# Processing Record 27 of Set 3 | vestmanna
# Processing Record 28 of Set 3 | taitung
# Processing Record 29 of Set 3 | kodiak
# Processing Record 30 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 3 | botro
# Processing Record 32 of Set 3 | buchanan
# Processing Record 33 of Set 3 | quatre cocos
# Processing Record 34 of Set 3 | tucurui
# Processing Record 35 of Set 3 | iquitos
# Processing Record 36 of Set 3 | mayo
# Processing Record 37 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 3 | puerto ayora
# Processing Record 39 of Set 3 | lexington
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | ribeira brava
# Processing Record 42 of Set 3 | bardiyah
# Processing Record 43 of Set 3 | yellowknife
# Processing Record 44 of Set 3 | mogadishu
# Processing Record 45 of Set 3 | henties bay
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | peachland
# Processing Record 48 of Set 3 | codajas
# Processing Record 49 of Set 3 | bredasdorp
# Processing Record 50 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 4 | yulara
# Processing Record 2 of Set 4 | sabla
# Processing Record 3 of Set 4 | kiruna
# Processing Record 4 of Set 4 | miles city
# Processing Record 5 of Set 4 | margate
# Processing Record 6 of Set 4 | tumbi
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | massakory
# Processing Record 9 of Set 4 | dingle
# Processing Record 10 of Set 4 | cherskiy
# Processing Record 11 of Set 4 | sur
# Processing Record 12 of Set 4 | linfen
# Processing Record 13 of Set 4 | les cayes
# Processing Record 14 of Set 4 | notre-dame-du-lac
# Processing Record 15 of Set 4 | plettenberg bay
# Processing Record 16 of Set 4 | burica
# City not found. Skipping...
# Processing Record 17 of Set 4 | portland
# Processing Record 18 of Set 4 | camopi
# Processing Record 19 of Set 4 | ketchikan
# Processing Record 20 of Set 4 | hambantota
# Processing Record 21 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 22 of Set 4 | kitgum
# Processing Record 23 of Set 4 | anju
# Processing Record 24 of Set 4 | mineiros
# Processing Record 25 of Set 4 | oktyabrskiy
# Processing Record 26 of Set 4 | ashland
# Processing Record 27 of Set 4 | upernavik
# Processing Record 28 of Set 4 | rjukan
# Processing Record 29 of Set 4 | san cristobal
# Processing Record 30 of Set 4 | zaysan
# Processing Record 31 of Set 4 | neiafu
# Processing Record 32 of Set 4 | aykhal
# Processing Record 33 of Set 4 | qaanaaq
# Processing Record 34 of Set 4 | port hawkesbury
# Processing Record 35 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 4 | amga
# Processing Record 37 of Set 4 | mahebourg
# Processing Record 38 of Set 4 | batagay
# Processing Record 39 of Set 4 | thompson
# Processing Record 40 of Set 4 | guaratinga
# Processing Record 41 of Set 4 | tambovka
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | sinnamary
# Processing Record 44 of Set 4 | port augusta
# Processing Record 45 of Set 4 | ballina
# Processing Record 46 of Set 4 | kapaa
# Processing Record 47 of Set 4 | lompoc
# Processing Record 48 of Set 4 | necochea
# Processing Record 49 of Set 4 | ajaccio
# Processing Record 50 of Set 4 | assiniboia
# Processing Record 1 of Set 5 | saint-philippe
# Processing Record 2 of Set 5 | beira
# Processing Record 3 of Set 5 | zhangye
# Processing Record 4 of Set 5 | alugan
# Processing Record 5 of Set 5 | longyearbyen
# Processing Record 6 of Set 5 | kapit
# Processing Record 7 of Set 5 | kaitangata
# Processing Record 8 of Set 5 | cabo san lucas
# Processing Record 9 of Set 5 | tamandare
# Processing Record 10 of Set 5 | lagoa
# Processing Record 11 of Set 5 | cayenne
# Processing Record 12 of Set 5 | neijiang
# Processing Record 13 of Set 5 | manzhouli
# Processing Record 14 of Set 5 | luderitz
# Processing Record 15 of Set 5 | yuli
# Processing Record 16 of Set 5 | mantua
# Processing Record 17 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 18 of Set 5 | cape town
# Processing Record 19 of Set 5 | lewisville
# Processing Record 20 of Set 5 | torbay
# Processing Record 21 of Set 5 | goderich
# Processing Record 22 of Set 5 | warmbad
# Processing Record 23 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 5 | arraial do cabo
# Processing Record 25 of Set 5 | sangeorgiu-de-padure
# City not found. Skipping...
# Processing Record 26 of Set 5 | morondava
# Processing Record 27 of Set 5 | balgazyn
# Processing Record 28 of Set 5 | fershampenuaz
# Processing Record 29 of Set 5 | alofi
# Processing Record 30 of Set 5 | mehamn
# Processing Record 31 of Set 5 | kandi
# Processing Record 32 of Set 5 | yerbogachen
# Processing Record 33 of Set 5 | chernyshevskiy
# Processing Record 34 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 5 | kudahuvadhoo
# Processing Record 36 of Set 5 | sakakah
# Processing Record 37 of Set 5 | severo-kurilsk
# Processing Record 38 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 39 of Set 5 | meulaboh
# Processing Record 40 of Set 5 | fortuna
# Processing Record 41 of Set 5 | kalmunai
# Processing Record 42 of Set 5 | arica
# Processing Record 43 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 5 | ewa beach
# Processing Record 45 of Set 5 | koslan
# Processing Record 46 of Set 5 | hervey bay
# Processing Record 47 of Set 5 | manta
# Processing Record 48 of Set 5 | haines junction
# Processing Record 49 of Set 5 | zeya
# Processing Record 50 of Set 5 | taoudenni
# Processing Record 1 of Set 6 | san carlos de bariloche
# Processing Record 2 of Set 6 | bac lieu
# Processing Record 3 of Set 6 | ribeira grande
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | college
# Processing Record 6 of Set 6 | tahoua
# Processing Record 7 of Set 6 | juneau
# Processing Record 8 of Set 6 | bambanglipuro
# Processing Record 9 of Set 6 | kazerun
# Processing Record 10 of Set 6 | beringovskiy
# Processing Record 11 of Set 6 | nelson
# Processing Record 12 of Set 6 | huitziltepec
# Processing Record 13 of Set 6 | balimo
# City not found. Skipping...
# Processing Record 14 of Set 6 | noumea
# Processing Record 15 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 6 | talnakh
# Processing Record 17 of Set 6 | byron bay
# Processing Record 18 of Set 6 | kamaishi
# Processing Record 19 of Set 6 | turukhansk
# Processing Record 20 of Set 6 | otradnoye
# Processing Record 21 of Set 6 | okhotsk
# Processing Record 22 of Set 6 | abnub
# Processing Record 23 of Set 6 | ukiah
# Processing Record 24 of Set 6 | flic en flac
# Processing Record 25 of Set 6 | pak phanang
# Processing Record 26 of Set 6 | ginda
# Processing Record 27 of Set 6 | saskylakh
# Processing Record 28 of Set 6 | kalga
# Processing Record 29 of Set 6 | codrington
# Processing Record 30 of Set 6 | ancud
# Processing Record 31 of Set 6 | port macquarie
# Processing Record 32 of Set 6 | boa vista
# Processing Record 33 of Set 6 | lavrentiya
# Processing Record 34 of Set 6 | touros
# Processing Record 35 of Set 6 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 36 of Set 6 | bengkulu
# Processing Record 37 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 6 | kirakira
# Processing Record 39 of Set 6 | monrovia
# Processing Record 40 of Set 6 | miranda
# Processing Record 41 of Set 6 | buala
# Processing Record 42 of Set 6 | lachhmangarh
# Processing Record 43 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 6 | teya
# Processing Record 45 of Set 6 | kruisfontein
# Processing Record 46 of Set 6 | ust-maya
# Processing Record 47 of Set 6 | ilulissat
# Processing Record 48 of Set 6 | san carlos del zulia
# Processing Record 49 of Set 6 | jose de freitas
# Processing Record 50 of Set 6 | serowe
# Processing Record 1 of Set 7 | cockburn town
# Processing Record 2 of Set 7 | manakara
# Processing Record 3 of Set 7 | la ronge
# Processing Record 4 of Set 7 | road town
# Processing Record 5 of Set 7 | saint-francois
# Processing Record 6 of Set 7 | san rafael
# Processing Record 7 of Set 7 | inirida
# Processing Record 8 of Set 7 | colotlan
# Processing Record 9 of Set 7 | werda
# Processing Record 10 of Set 7 | sterling
# Processing Record 11 of Set 7 | sarh
# Processing Record 12 of Set 7 | okha
# Processing Record 13 of Set 7 | talmenka
# Processing Record 14 of Set 7 | mega
# Processing Record 15 of Set 7 | yendi
# Processing Record 16 of Set 7 | sioux lookout
# Processing Record 17 of Set 7 | port hueneme
# Processing Record 18 of Set 7 | lander
# Processing Record 19 of Set 7 | broken hill
# Processing Record 20 of Set 7 | srednekolymsk
# Processing Record 21 of Set 7 | coxim
# Processing Record 22 of Set 7 | camana
# Processing Record 23 of Set 7 | bathsheba
# Processing Record 24 of Set 7 | barberton
# Processing Record 25 of Set 7 | clearwater
# Processing Record 26 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 7 | la romana
# Processing Record 28 of Set 7 | uryupinsk
# Processing Record 29 of Set 7 | ayr
# Processing Record 30 of Set 7 | coahuayana
# Processing Record 31 of Set 7 | parlakimidi
# Processing Record 32 of Set 7 | nuuk
# Processing Record 33 of Set 7 | erenhot
# Processing Record 34 of Set 7 | kaniama
# Processing Record 35 of Set 7 | sterlibashevo
# Processing Record 36 of Set 7 | los llanos de aridane
# Processing Record 37 of Set 7 | baruun-urt
# Processing Record 38 of Set 7 | aconibe
# Processing Record 39 of Set 7 | kribi
# Processing Record 40 of Set 7 | port hedland
# Processing Record 41 of Set 7 | sao filipe
# Processing Record 42 of Set 7 | bykovo
# Processing Record 43 of Set 7 | raga
# Processing Record 44 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | san pedro
# Processing Record 46 of Set 7 | faya
# Processing Record 47 of Set 7 | riyadh
# Processing Record 48 of Set 7 | port lincoln
# Processing Record 49 of Set 7 | sao felix do xingu
# Processing Record 50 of Set 7 | araouane
# Processing Record 1 of Set 8 | carndonagh
# Processing Record 2 of Set 8 | ranong
# Processing Record 3 of Set 8 | whitianga
# Processing Record 4 of Set 8 | alice springs
# Processing Record 5 of Set 8 | pangnirtung
# Processing Record 6 of Set 8 | vila velha
# Processing Record 7 of Set 8 | diego de almagro
# Processing Record 8 of Set 8 | panguna
# Processing Record 9 of Set 8 | birjand
# Processing Record 10 of Set 8 | avera
# Processing Record 11 of Set 8 | krasnyy chikoy
# Processing Record 12 of Set 8 | bolitoc
# Processing Record 13 of Set 8 | santiago
# Processing Record 14 of Set 8 | manyana
# Processing Record 15 of Set 8 | udachnyy
# Processing Record 16 of Set 8 | wundanyi
# Processing Record 17 of Set 8 | khingansk
# Processing Record 18 of Set 8 | broome
# Processing Record 19 of Set 8 | havoysund
# Processing Record 20 of Set 8 | talara
# Processing Record 21 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 8 | ulladulla
# Processing Record 23 of Set 8 | penzance
# Processing Record 24 of Set 8 | malatya
# Processing Record 25 of Set 8 | charters towers
# Processing Record 26 of Set 8 | sitarganj
# Processing Record 27 of Set 8 | ashibetsu
# Processing Record 28 of Set 8 | stornoway
# Processing Record 29 of Set 8 | kenai
# Processing Record 30 of Set 8 | reforma
# Processing Record 31 of Set 8 | jiwani
# Processing Record 32 of Set 8 | adrar
# Processing Record 33 of Set 8 | chuy
# Processing Record 34 of Set 8 | esil
# Processing Record 35 of Set 8 | goma
# Processing Record 36 of Set 8 | kachikau
# City not found. Skipping...
# Processing Record 37 of Set 8 | souillac
# Processing Record 38 of Set 8 | norman wells
# Processing Record 39 of Set 8 | port-gentil
# Processing Record 40 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | maumere
# Processing Record 42 of Set 8 | genhe
# Processing Record 43 of Set 8 | auki
# Processing Record 44 of Set 8 | pacific grove
# Processing Record 45 of Set 8 | ures
# Processing Record 46 of Set 8 | guasdualito
# Processing Record 47 of Set 8 | maceio
# Processing Record 48 of Set 8 | contai
# Processing Record 49 of Set 8 | bumba
# Processing Record 50 of Set 8 | baracoa
# Processing Record 1 of Set 9 | novikovo
# Processing Record 2 of Set 9 | kysyl-syr
# Processing Record 3 of Set 9 | suez
# Processing Record 4 of Set 9 | paamiut
# Processing Record 5 of Set 9 | todos santos
# Processing Record 6 of Set 9 | thinadhoo
# Processing Record 7 of Set 9 | ponta do sol
# Processing Record 8 of Set 9 | yar-sale
# Processing Record 9 of Set 9 | indramayu
# Processing Record 10 of Set 9 | huilong
# Processing Record 11 of Set 9 | bayir
# Processing Record 12 of Set 9 | barranca
# Processing Record 13 of Set 9 | inhambane
# Processing Record 14 of Set 9 | prado
# Processing Record 15 of Set 9 | verdalsora
# City not found. Skipping...
# Processing Record 16 of Set 9 | kalaleh
# Processing Record 17 of Set 9 | port moresby
# Processing Record 18 of Set 9 | nantucket
# Processing Record 19 of Set 9 | urucara
# Processing Record 20 of Set 9 | isangel
# Processing Record 21 of Set 9 | billings
# Processing Record 22 of Set 9 | ponta delgada
# Processing Record 23 of Set 9 | namatanai
# Processing Record 24 of Set 9 | tuatapere
# Processing Record 25 of Set 9 | emerald
# Processing Record 26 of Set 9 | southbridge
# Processing Record 27 of Set 9 | fare
# Processing Record 28 of Set 9 | chulman
# Processing Record 29 of Set 9 | herat
# Processing Record 30 of Set 9 | shimoda
# Processing Record 31 of Set 9 | douglas
# Processing Record 32 of Set 9 | half moon bay
# Processing Record 33 of Set 9 | ostrovnoy
# Processing Record 34 of Set 9 | boguchany
# Processing Record 35 of Set 9 | petatlan
# Processing Record 36 of Set 9 | gombong
# Processing Record 37 of Set 9 | egvekinot
# Processing Record 38 of Set 9 | dali
# Processing Record 39 of Set 9 | khandyga
# Processing Record 40 of Set 9 | pahrump
# Processing Record 41 of Set 9 | apac
# Processing Record 42 of Set 9 | jinxiang
# Processing Record 43 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 44 of Set 9 | taiyuan
# Processing Record 45 of Set 9 | samarai
# Processing Record 46 of Set 9 | zaoyang
# Processing Record 47 of Set 9 | the valley
# Processing Record 48 of Set 9 | gushikawa
# Processing Record 49 of Set 9 | piracuruca
# Processing Record 50 of Set 9 | labuhan
# Processing Record 1 of Set 10 | ostuman
# City not found. Skipping...
# Processing Record 2 of Set 10 | amarpur
# Processing Record 3 of Set 10 | kargil
# Processing Record 4 of Set 10 | kozyatyn
# Processing Record 5 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 10 | belyy yar
# Processing Record 7 of Set 10 | catuday
# Processing Record 8 of Set 10 | bilibino
# Processing Record 9 of Set 10 | karratha
# Processing Record 10 of Set 10 | huarmey
# Processing Record 11 of Set 10 | bengkalis
# City not found. Skipping...
# Processing Record 12 of Set 10 | vila franca do campo
# Processing Record 13 of Set 10 | kanye
# Processing Record 14 of Set 10 | brigantine
# Processing Record 15 of Set 10 | lorengau
# Processing Record 16 of Set 10 | saint-pierre
# Processing Record 17 of Set 10 | richards bay
# Processing Record 18 of Set 10 | tazovskiy
# Processing Record 19 of Set 10 | hofn
# Processing Record 20 of Set 10 | seoul
# Processing Record 21 of Set 10 | narasannapeta
# Processing Record 22 of Set 10 | biak
# Processing Record 23 of Set 10 | afmadu
# City not found. Skipping...
# Processing Record 24 of Set 10 | kieta
# Processing Record 25 of Set 10 | sangar
# Processing Record 26 of Set 10 | hobyo
# Processing Record 27 of Set 10 | celestun
# Processing Record 28 of Set 10 | tuku
# Processing Record 29 of Set 10 | kadaura
# Processing Record 30 of Set 10 | sorland
# Processing Record 31 of Set 10 | dawson creek
# Processing Record 32 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 10 | kholmogory
# Processing Record 34 of Set 10 | enshi
# Processing Record 35 of Set 10 | nanakuli
# Processing Record 36 of Set 10 | komsomolskiy
# Processing Record 37 of Set 10 | sabaudia
# Processing Record 38 of Set 10 | kushiro
# Processing Record 39 of Set 10 | alyangula
# Processing Record 40 of Set 10 | kapoeta
# Processing Record 41 of Set 10 | bandarbeyla
# Processing Record 42 of Set 10 | sao gabriel da cachoeira
# Processing Record 43 of Set 10 | nabire
# Processing Record 44 of Set 10 | ndele
# Processing Record 45 of Set 10 | caucaia
# Processing Record 46 of Set 10 | ambilobe
# Processing Record 47 of Set 10 | vao
# Processing Record 48 of Set 10 | rawson
# Processing Record 49 of Set 10 | sembe
# Processing Record 50 of Set 10 | fort nelson
# Processing Record 1 of Set 11 | mount gambier
# Processing Record 2 of Set 11 | voyvozh
# Processing Record 3 of Set 11 | saldanha
# Processing Record 4 of Set 11 | grindavik
# Processing Record 5 of Set 11 | port hardy
# Processing Record 6 of Set 11 | bahia honda
# Processing Record 7 of Set 11 | pala
# Processing Record 8 of Set 11 | ust-ordynskiy
# Processing Record 9 of Set 11 | raxaul
# Processing Record 10 of Set 11 | naze
# Processing Record 11 of Set 11 | corumba
# Processing Record 12 of Set 11 | along
# Processing Record 13 of Set 11 | upata
# Processing Record 14 of Set 11 | heilbron
# Processing Record 15 of Set 11 | venice
# Processing Record 16 of Set 11 | aviemore
# Processing Record 17 of Set 11 | mabama
# Processing Record 18 of Set 11 | a coruna
# Processing Record 19 of Set 11 | remontnoye
# Processing Record 20 of Set 11 | tateyama
# Processing Record 21 of Set 11 | florianopolis
# Processing Record 22 of Set 11 | boshnyakovo
# Processing Record 23 of Set 11 | saint-georges
# Processing Record 24 of Set 11 | botelhos
# Processing Record 25 of Set 11 | rio claro
# Processing Record 26 of Set 11 | vostok
# Processing Record 27 of Set 11 | serra
# Processing Record 28 of Set 11 | satun
# Processing Record 29 of Set 11 | buraydah
# Processing Record 30 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 31 of Set 11 | surt
# Processing Record 32 of Set 11 | vysokogornyy
# Processing Record 33 of Set 11 | male
# Processing Record 34 of Set 11 | khunti
# Processing Record 35 of Set 11 | scottsbluff
# Processing Record 36 of Set 11 | makat
# Processing Record 37 of Set 11 | nelson bay
# Processing Record 38 of Set 11 | san luis
# Processing Record 39 of Set 11 | xichang
# Processing Record 40 of Set 11 | chalus
# Processing Record 41 of Set 11 | kampong cham
# Processing Record 42 of Set 11 | omboue
# Processing Record 43 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 11 | lodja
# Processing Record 45 of Set 11 | gaoua
# Processing Record 46 of Set 11 | luau
# Processing Record 47 of Set 11 | mazagao
# Processing Record 48 of Set 11 | serenje
# Processing Record 49 of Set 11 | sao miguel do araguaia
# Processing Record 50 of Set 11 | lakes entrance
# Processing Record 1 of Set 12 | saint anthony
# Processing Record 2 of Set 12 | wasilla
# Processing Record 3 of Set 12 | xai-xai
# Processing Record 4 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 5 of Set 12 | venado tuerto
# Processing Record 6 of Set 12 | havre-saint-pierre
# Processing Record 7 of Set 12 | cartagena
# Processing Record 8 of Set 12 | asau
# Processing Record 9 of Set 12 | flinders
# Processing Record 10 of Set 12 | the pas
# Processing Record 11 of Set 12 | east london
# Processing Record 12 of Set 12 | mindelo
# Processing Record 13 of Set 12 | teacapan
# Processing Record 14 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 12 | strezhevoy
# Processing Record 16 of Set 12 | bam
# Processing Record 17 of Set 12 | mishkino
# Processing Record 18 of Set 12 | nova olinda do norte
# Processing Record 19 of Set 12 | khakhea
# Processing Record 20 of Set 12 | noyabrsk
# Processing Record 21 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 12 | tabou
# Processing Record 23 of Set 12 | amahai
# Processing Record 24 of Set 12 | san lorenzo
# Processing Record 25 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 12 | atherton
# Processing Record 27 of Set 12 | mackenzie
# Processing Record 28 of Set 12 | mount isa
# Processing Record 29 of Set 12 | tura
# Processing Record 30 of Set 12 | carutapera
# Processing Record 31 of Set 12 | lesozavodsk
# Processing Record 32 of Set 12 | mahanoro
# Processing Record 33 of Set 12 | goure
# Processing Record 34 of Set 12 | sao jose da coroa grande
# Processing Record 35 of Set 12 | lampang
# Processing Record 36 of Set 12 | las lomas
# Processing Record 37 of Set 12 | raipur
# Processing Record 38 of Set 12 | portree
# Processing Record 39 of Set 12 | kota kinabalu
# Processing Record 40 of Set 12 | harrai
# Processing Record 41 of Set 12 | puerto del rosario
# Processing Record 42 of Set 12 | gat
# Processing Record 43 of Set 12 | ekibastuz
# Processing Record 44 of Set 12 | roma
# Processing Record 45 of Set 12 | hauterive
# Processing Record 46 of Set 12 | puerto suarez
# Processing Record 47 of Set 12 | lerwick
# Processing Record 48 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 12 | padang
# Processing Record 50 of Set 12 | daru
# Processing Record 1 of Set 13 | santo domingo
# Processing Record 2 of Set 13 | syamzha
# Processing Record 3 of Set 13 | la grande
# Processing Record 4 of Set 13 | talaya
# Processing Record 5 of Set 13 | yurya
# City not found. Skipping...
# Processing Record 6 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 7 of Set 13 | nanortalik
# Processing Record 8 of Set 13 | kalomo
# City not found. Skipping...
# Processing Record 9 of Set 13 | itoman
# Processing Record 10 of Set 13 | coffs harbour
# Processing Record 11 of Set 13 | rio brilhante
# Processing Record 12 of Set 13 | santa cruz
# Processing Record 13 of Set 13 | abha
# Processing Record 14 of Set 13 | carballo
# Processing Record 15 of Set 13 | honiara
# Processing Record 16 of Set 13 | wajima
# Processing Record 17 of Set 13 | calvinia
# Processing Record 18 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 19 of Set 13 | tupiza
# Processing Record 20 of Set 13 | launceston
# Processing Record 21 of Set 13 | san policarpo
# Processing Record 22 of Set 13 | pacifica
# Processing Record 23 of Set 13 | hutchinson
# Processing Record 24 of Set 13 | salinas
# Processing Record 25 of Set 13 | aksarka
# Processing Record 26 of Set 13 | kotovo
# Processing Record 27 of Set 13 | mareeba
# Processing Record 28 of Set 13 | kifri
# Processing Record 29 of Set 13 | poum
# Processing Record 30 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 31 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 32 of Set 13 | ndola
# Processing Record 33 of Set 13 | kavaratti
# Processing Record 34 of Set 13 | hastings
# Processing Record 35 of Set 13 | basco
# Processing Record 36 of Set 13 | omsukchan
# Processing Record 37 of Set 13 | nawa
# Processing Record 38 of Set 13 | watertown
# Processing Record 39 of Set 13 | altagracia de orituco
# Processing Record 40 of Set 13 | hami
# Processing Record 41 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 42 of Set 13 | akureyri
# Processing Record 43 of Set 13 | markova
# Processing Record 44 of Set 13 | newport
# Processing Record 45 of Set 13 | maragogi
# Processing Record 46 of Set 13 | san juan
# Processing Record 47 of Set 13 | nhulunbuy
# Processing Record 48 of Set 13 | kyzyl-suu
# Processing Record 49 of Set 13 | batagay-alyta
# Processing Record 50 of Set 13 | tromso
# Processing Record 1 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 14 | betanzos
# Processing Record 3 of Set 14 | matadi
# Processing Record 4 of Set 14 | vorona
# Processing Record 5 of Set 14 | buguruslan
# Processing Record 6 of Set 14 | loralai
# Processing Record 7 of Set 14 | tiarei
# Processing Record 8 of Set 14 | mzimba
# Processing Record 9 of Set 14 | rocha
# Processing Record 10 of Set 14 | yongan
# Processing Record 11 of Set 14 | eydhafushi
# Processing Record 12 of Set 14 | marsa matruh
# Processing Record 13 of Set 14 | severo-yeniseyskiy
# Processing Record 14 of Set 14 | kununurra
# Processing Record 15 of Set 14 | sabanagrande
# Processing Record 16 of Set 14 | rehburg-loccum
# Processing Record 17 of Set 14 | oparino
# Processing Record 18 of Set 14 | gigmoto
# Processing Record 19 of Set 14 | gatton
# Processing Record 20 of Set 14 | moose factory
# Processing Record 21 of Set 14 | dongsheng
# Processing Record 22 of Set 14 | high rock
# Processing Record 23 of Set 14 | santa marta
# Processing Record 24 of Set 14 | oistins
# Processing Record 25 of Set 14 | ruwi
# Processing Record 26 of Set 14 | hamilton
# Processing Record 27 of Set 14 | walvis bay
# Processing Record 28 of Set 14 | saint-augustin
# Processing Record 29 of Set 14 | bonavista
# Processing Record 30 of Set 14 | caldas da rainha
# Processing Record 31 of Set 14 | warrington
# Processing Record 32 of Set 14 | slonim
# Processing Record 33 of Set 14 | banjar
# Processing Record 34 of Set 14 | nurota
# Processing Record 35 of Set 14 | salas
# Processing Record 36 of Set 14 | champerico
# Processing Record 37 of Set 14 | paso de los toros
# Processing Record 38 of Set 14 | nanning
# Processing Record 39 of Set 14 | sisimiut
# Processing Record 40 of Set 14 | blagoyevo
# Processing Record 41 of Set 14 | port blair
# Processing Record 42 of Set 14 | zhuanghe
# Processing Record 43 of Set 14 | vanimo
# Processing Record 44 of Set 14 | ambon
# Processing Record 45 of Set 14 | garmsar
# Processing Record 46 of Set 14 | dhidhdhoo
# Processing Record 47 of Set 14 | itubera
# Processing Record 48 of Set 14 | atar
# Processing Record 49 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 14 | terrak
# Processing Record 1 of Set 15 | zlatna
# Processing Record 2 of Set 15 | monster
# Processing Record 3 of Set 15 | batemans bay
# Processing Record 4 of Set 15 | banda aceh
# Processing Record 5 of Set 15 | suratgarh
# Processing Record 6 of Set 15 | sorong
# Processing Record 7 of Set 15 | beloha
# Processing Record 8 of Set 15 | berlevag
# Processing Record 9 of Set 15 | belmonte
# Processing Record 10 of Set 15 | chimbote
# Processing Record 11 of Set 15 | caravelas
# Processing Record 12 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 13 of Set 15 | gizo
# Processing Record 14 of Set 15 | zarya
# Processing Record 15 of Set 15 | kpandae
# Processing Record 16 of Set 15 | kropotkin
# Processing Record 17 of Set 15 | tornio
# Processing Record 18 of Set 15 | pierre
# Processing Record 19 of Set 15 | mitu
# Processing Record 20 of Set 15 | bereda
# Processing Record 21 of Set 15 | merauke
# Processing Record 22 of Set 15 | nowy dwor gdanski
# Processing Record 23 of Set 15 | mandera
# Processing Record 24 of Set 15 | uige
# Processing Record 25 of Set 15 | acapulco
# Processing Record 26 of Set 15 | jizan
# Processing Record 27 of Set 15 | cabra
# Processing Record 28 of Set 15 | mildura
# Processing Record 29 of Set 15 | neryungri
# Processing Record 30 of Set 15 | castra-nova
# Processing Record 31 of Set 15 | intipuca
# Processing Record 32 of Set 15 | jiayuguan
# Processing Record 33 of Set 15 | rongcheng
# Processing Record 34 of Set 15 | bratsk
# Processing Record 35 of Set 15 | shizunai
# Processing Record 36 of Set 15 | waverly
# Processing Record 37 of Set 15 | pisco
# Processing Record 38 of Set 15 | burnie
# Processing Record 39 of Set 15 | el faiyum
# City not found. Skipping...
# Processing Record 40 of Set 15 | yagodnoye
# Processing Record 41 of Set 15 | shitanjing
# Processing Record 42 of Set 15 | dandong
# Processing Record 43 of Set 15 | jumla
# Processing Record 44 of Set 15 | banepa
# Processing Record 45 of Set 15 | luanda
# Processing Record 46 of Set 15 | tourlaville
# Processing Record 47 of Set 15 | gusau
# Processing Record 48 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 15 | arlit
# Processing Record 50 of Set 15 | camara de lobos
# Processing Record 1 of Set 16 | wentzville
# Processing Record 2 of Set 16 | muroto
# Processing Record 3 of Set 16 | ozernovskiy
# Processing Record 4 of Set 16 | khani
# Processing Record 5 of Set 16 | praia da vitoria
# Processing Record 6 of Set 16 | urk
# Processing Record 7 of Set 16 | eureka
# Processing Record 8 of Set 16 | nador
# Processing Record 9 of Set 16 | makasar
# Processing Record 10 of Set 16 | tukrah
# Processing Record 11 of Set 16 | comodoro rivadavia
# Processing Record 12 of Set 16 | ilo
# Processing Record 13 of Set 16 | bridlington
# Processing Record 14 of Set 16 | tacuati
# Processing Record 15 of Set 16 | phangnga
# Processing Record 16 of Set 16 | chapais
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Calama      CL -22.4667  -68.9333     52.29        17           0
# 1      Wabash      US  40.7978  -85.8205     81.12        74           4
# 2       Bluff      NZ -46.6000  168.3333     41.81        58          82
# 3        Sola      VU -13.8833  167.5500     80.17        79          94
# 4    Katsuura      JP  35.1333  140.3000     73.71        87          58
# 5     Rikitea      PF -23.1203 -134.9692     75.58        73           9
# 6    Ahuimanu      US  21.4447 -157.8378     83.34        64          75
# 7  Chokurdakh      RU  70.6333  147.9167     44.94        47          88
# 8     Itarema      BR  -2.9248  -39.9167     74.44        86         100
# 9   Hithadhoo      MV  -0.6000   73.0833     83.93        69          36
#
#    Wind Speed Current Description
# 0       16.11           clear sky
# 1        7.18           clear sky
# 2        6.38       broken clouds
# 3       17.74     overcast clouds
# 4        9.48       broken clouds
# 5       13.56           clear sky
# 6       16.11          light rain
# 7       16.24     overcast clouds
# 8        9.35     overcast clouds
# 9       10.65    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
